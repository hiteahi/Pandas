# %% [markdown]
# # Data Type Validation
# Always validate data types before analysis or modeling, as incorrect types can silently produce wrong results.

# %% [markdown]
# ## Dataset Summary
# - **Mixed-Type Numeric (age)**: Contains integers, floats, strings like `42 years`, and non-numeric labels like `Unknown`.
# - **Object-Typed Numbers (salary)**: Numbers are stored as strings because of formatting (commas, dollar signs, and decimals).
# - **Inconsistent Dates (date of joining)**: Uses multiple formats like `DD-MM-YYYY`, `YYYY/MM/DD`, and `Month DD, YYYY`.
# - **The Boolean Mess (is_full_time)**: A common real-world problem where "True" is represented by `1`, `Yes`, `True`, `No`, `0`, etc.

# %%
import pandas as pd, numpy as np

# %%
df = pd.read_csv("10_datatype_validation.csv")
df
# Out:
#          name  gender       age   salary       city date of joining  \
# 0        Amit    Male        28    40769    Kolkata      30-10-2021
# 1        Riya  Female        41    99735       Pune      09-02-2018
# 2        John    Male        36   96,101       Pune      02-06-2019
# 3        Neha  Female        32  42433.5    Kolkata      04-03-2020
# 4   Siddharth    Male        29    45311       Pune      15-10-2022
# 5         Zoe  Female  42 years    77819  Bangalore      28-11-2023
# 6         Ken    Male        28    79188    Chennai      12-05-2018
# 7      Anjali  Female        47    57568    Kolkata      25-10-2020
# 8       Vijay    Male        40   $93707    Chennai      06-09-2022
# 9       Priya  Female        44    59769      Delhi      03-09-2022
# 10      Rahul    Male   Unknown    68693  Bangalore      09-03-2020
# 11      Sonia  Female        32    46396  Hyderabad      13-03-2019
# 12       Mike    Male        45    67480  Bangalore     Feb 9, 2023
# 13       Sara  Female        42    81434    Kolkata      24-09-2018
# 14      David    Male        25    65658  Hyderabad      24-09-2020
# 15       Emma  Female        29    58942      Delhi      13-10-2020
# 16       Liam    Male        45    97001    Kolkata      16-09-2018
# 17     Olivia  Female        24    58431     Mumbai      06-04-2022
# 18        Raj    Male        43    42747    Chennai      14-05-2022
# 19     Simran  Female        42    98319      Delhi      20-01-2022
#
#    is_full_time
# 0          TRUE
# 1           Yes
# 2             1
# 3          TRUE
# 4          TRUE
# 5          TRUE
# 6          TRUE
# 7          TRUE
# 8          TRUE
# 9          TRUE
# 10           No
# 11            0
# 12         TRUE
# 13         TRUE
# 14         TRUE
# 15        FALSE
# 16         TRUE
# 17         TRUE
# 18         TRUE
# 19         TRUE

# %% [markdown]
# ## Before memory usage:

# %%
df.memory_usage(deep=True)
# Out:
# Index               132
# name               1073
# gender             1080
# age                1031
# salary             1084
# city               1114
# date of joining    1181
# is_full_time       1052
# dtype: int64

# %% [markdown]
# ## Clean and Convert Numeric Columns

# %% [markdown]
# ### Handle `age` Column
# -  `Int64(nullable)` for Missing Values (NaN)
# - `errors='coerce'` turns `Unknown` into NaN
# - Use `Int8` for `Memory-critical`

# %%
df['age'] = df['age'].str.replace(' years', '') # Remove the ' years' suffix from the age column
df['age'] = pd.to_numeric(df['age'].str.replace(' years', ''), errors='coerce').astype('Int64')

# %% [markdown]
# **Note**: `errors='coerce'` converts invalid values to NaN, which should be handled explicitly afterward.

# %% [markdown]
# ### Handle `salary` Column
# Strip symbols and commas before converting

# %%
df['salary'] = df['salary'].str.replace(r'[$,]', '', regex=True)
df['salary'] = pd.to_numeric(df['salary'], errors='coerce')

# %% [markdown]
# ### .apply() → Apply any function to rows or columns
#  if Juniors salary less than and equel to 75000 and Seniors age more than 75000

# %%
df["Junior or Senions"] = df["salary"].apply(lambda age: "Senions" if age >= 75000 else "Junior")

# %% [markdown]
# ## Standardize Date Formats

# %% [markdown]
# ### Handle `date of joining` Column

# %%
df['date of joining'] = pd.to_datetime(df['date of joining'], format='mixed', dayfirst=True, errors='coerce')

# %% [markdown]
# ## Map Booleans

# %% [markdown]
# ### Handle `is_full_time` Column

# %%
bool_map = {
    'true': True, 'yes': True, 1: True, '1': True,
    'false': False, 'no': False, 0: False, '0': False
}
df['is_full_time'] = df['is_full_time'].astype(str).str.lower()
df['is_full_time'] = df['is_full_time'].map(bool_map).astype('boolean')

# %%
df[['gender', 'city']].memory_usage(deep=True)
# Out:
# Index      132
# gender    1080
# city      1114
# dtype: int64

# %% [markdown]
# ## Conversion to 'category' type

# %% [markdown]
# ### Handle `gender` Column

# %%
# Before converting to categories, we must ensure 'Male' and 'male' are treated as the same
df['gender'] = df['gender'].str.strip().str.capitalize()
df['gender'] = df['gender'].astype('category')

# %% [markdown]
# ### Handle `city` Column

# %%
df['city'] = df['city'].str.strip().str.title()
df['city'] = df['city'].astype('category')
df
# Out:
#          name  gender   age   salary       city date of joining  is_full_time  \
# 0        Amit    Male    28  40769.0    Kolkata      2021-10-30          True
# 1        Riya  Female    41  99735.0       Pune      2018-02-09          True
# 2        John    Male    36  96101.0       Pune      2019-06-02          True
# 3        Neha  Female    32  42433.5    Kolkata      2020-03-04          True
# 4   Siddharth    Male    29  45311.0       Pune      2022-10-15          True
# 5         Zoe  Female    42  77819.0  Bangalore      2023-11-28          True
# 6         Ken    Male    28  79188.0    Chennai      2018-05-12          True
# 7      Anjali  Female    47  57568.0    Kolkata      2020-10-25          True
# 8       Vijay    Male    40  93707.0    Chennai      2022-09-06          True
# 9       Priya  Female    44  59769.0      Delhi      2022-09-03          True
# 10      Rahul    Male  <NA>  68693.0  Bangalore      2020-03-09         False
# 11      Sonia  Female    32  46396.0  Hyderabad      2019-03-13         False
# 12       Mike    Male    45  67480.0  Bangalore      2023-02-09          True
# 13       Sara  Female    42  81434.0    Kolkata      2018-09-24          True
# 14      David    Male    25  65658.0  Hyderabad      2020-09-24          True
# 15       Emma  Female    29  58942.0      Delhi      2020-10-13         False
# 16       Liam    Male    45  97001.0    Kolkata      2018-09-16          True
# 17     Olivia  Female    24  58431.0     Mumbai      2022-04-06          True
# 18        Raj    Male    43  42747.0    Chennai      2022-05-14          True
# 19     Simran  Female    42  98319.0      Delhi      2022-01-20          True
#
#    Junior or Senions
# 0             Junior
# 1            Senions
# 2            Senions
# 3             Junior
# 4             Junior
# 5            Senions
# 6            Senions
# 7             Junior
# 8            Senions
# 9             Junior
# 10            Junior
# 11            Junior
# 12            Junior
# 13           Senions
# 14            Junior
# 15            Junior
# 16           Senions
# 17            Junior
# 18            Junior
# 19           Senions

# %% [markdown]
# ## Accessing Category Codes

# %%
df['city'].cat.codes.head()
# Out:
# 0    4
# 1    6
# 2    6
# 3    4
# 4    6
# dtype: int8

# %% [markdown]
# ## After memory usage

# %%
df.memory_usage(deep=True)
# Out:
# Index                 132
# name                 1073
# gender                236
# age                   180
# salary                160
# city                  710
# date of joining       160
# is_full_time           40
# Junior or Senions    1108
# dtype: int64

# %% [markdown]
# ## Summary
# - Data type validation is a critical cleaning step
# - Blind casting is dangerous
# - Correct types improve analysis and modeling reliability
